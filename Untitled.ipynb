# %% [markdown]
# GARCH MODEL

# %% [markdown]
# READ DATA

# %%
from datetime import datetime, timedelta
import pandas as pd
import matplotlib.pyplot as plt
from arch import arch_model
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import numpy as np

# %% [markdown]
# NIFTY50 Volatility

# %%
df = pd.read_csv("NIFTY 50-12-11-2023-to-12-11-2024.csv")

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close   Shares Traded   \
# 0  12-NOV-2023  19547.25  19547.25  19510.25  19525.55      37311902.0
# 1  13-NOV-2023  19486.75  19494.40  19414.75  19443.55     189275733.0
# 2  15-NOV-2023  19651.40  19693.20  19579.65  19675.45     291464988.0
# 3  16-NOV-2023  19674.70  19875.25  19627.00  19765.20     282686669.0
# 4  17-NOV-2023  19674.75  19806.00  19667.45  19731.80     236827462.0
#
#    Turnover (₹ Cr)
# 0          2482.27
# 1         13527.22
# 2         24957.24
# 3         26041.45
# 4         21681.28

# %%
print(df.columns)
# Out:
# Index(['Date ', 'Open ', 'High ', 'Low ', 'Close ', 'Shares Traded ',
#        'Turnover (₹ Cr)'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_25256\4215990141.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
returns = 100 * df['Close'].pct_change().dropna()
print(returns.head())
# Out:
# 1   -0.419963
# 2    1.192683
# 3    0.456152
# 4   -0.168984
# 5   -0.191569
# Name: Close, dtype: float64

# %%
plt.figure(figsize = (10, 4))
plt.plot(returns)
plt.ylabel("PCT returns", fontsize = 16)
plt.title('Nifty 50 retuns', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Nifty 50 retuns')

# %% [markdown]
# PACF

# %%
plot_pacf(returns**2)
plt.show()

# %% [markdown]
# Fit GRACH(1, 1)

# %%
model = arch_model(returns, p = 1, q = 1)

# %%
model_fit = model.fit()
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 12014112770.510487
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 148979124.1451282
# Iteration:      3,   Func. Count:     20,   Neg. LLF: 354.7508472717873
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 294.0218036306346
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 292.6291201982457
# Iteration:      6,   Func. Count:     39,   Neg. LLF: 289.6517902272519
# Iteration:      7,   Func. Count:     44,   Neg. LLF: 289.65175909107535
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 289.6517567370139
# Iteration:      9,   Func. Count:     53,   Neg. LLF: 289.65175673702186
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 289.6517567370139
#             Iterations: 9
#             Function evaluations: 53
#             Gradient evaluations: 9

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  Close   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -289.652
# Distribution:                  Normal   AIC:                           587.304
# Method:            Maximum Likelihood   BIC:                           601.357
#                                         No. Observations:                  248
# Date:                Tue, Nov 12 2024   Df Residuals:                      247
# Time:                        11:51:44   Df Model:                            1
#                                 Mean Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# mu             0.1137  5.071e-02      2.242  2.496e-02 [1.430e-02,  0.213]
#                               Volatility Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# omega          0.3159  7.075e-02      4.464  8.030e-06    [  0.177,  0.455]
# alpha[1]       0.2187      0.126      1.742  8.147e-02 [-2.734e-02,  0.465]
# beta[1]        0.2982      0.119      2.502  1.235e-02  [6.459e-02,  0.532]
# ===========================================================================
#
# Covariance estimator: robust
# """

# %%
model2 = arch_model(returns, p = 1, q = 0)

# %%
model2_fit = model2.fit()
# Out:
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 931.052134888334
# Iteration:      2,   Func. Count:     12,   Neg. LLF: 887.9404401965143
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 317.53835779464924
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 36980.067411582626
# Iteration:      5,   Func. Count:     29,   Neg. LLF: 291.71949486163646
# Iteration:      6,   Func. Count:     33,   Neg. LLF: 291.7156078483046
# Iteration:      7,   Func. Count:     37,   Neg. LLF: 291.7155633164539
# Iteration:      8,   Func. Count:     40,   Neg. LLF: 291.7155633164973
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 291.7155633164539
#             Iterations: 8
#             Function evaluations: 40
#             Gradient evaluations: 8

# %%
model2_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                       Constant Mean - ARCH Model Results
# ==============================================================================
# Dep. Variable:                  Close   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                       ARCH   Log-Likelihood:               -291.716
# Distribution:                  Normal   AIC:                           589.431
# Method:            Maximum Likelihood   BIC:                           599.971
#                                         No. Observations:                  248
# Date:                Tue, Nov 12 2024   Df Residuals:                      247
# Time:                        11:51:44   Df Model:                            1
#                                 Mean Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# mu             0.
.7144800602335578, 0.7112084486734538, 0.7124444552041669, 0.7093526127896886, 0.7060569013612135, 0.7028526146902437, 0.6999440989545551, 0.711959942657688, 0.7088538980195412, 0.705966479294735, 0.7034169647856028, 0.7053312856501754, 0.708866564999419, 0.7058723757085936, 0.8238476228727204, 3.398644256529552, 2.925791488486939, 2.0106066321834772, 1.7295220850521973, 1.120013654792292, 0.7999657064153194, 0.7228428287851558, 0.7074726606874767, 0.6975796918117891, 0.6992934823723163, 0.7030901967965488, 0.6844847328728668, 0.7069398465513294, 0.6797500047180084, 0.745337615540244, 0.7316223278384097, 0.746849573778629, 0.7035179245374187, 0.7014920133500218, 0.6784233090770702, 0.7110474235209305, 0.6697927028085645, 0.6517447898215705, 0.6471226415521015, 0.65620125447956, 0.7108405910971582, 0.6653860188882703, 0.7146133148780451, 0.6646984879208233, 0.6365312199998597, 0.6981441658583024, 0.9164522437711006, 0.7505294787747806, 0.686567678695292, 0.6806779867742716, 0.6499812630587403, 1.0332452722970162, 0.7967850680853573, 0.6971876741032681, 0.6683346985510852, 0.6485099383080428, 0.9142694483242112, 1.694497930697726, 1.06148142435416, 0.9912513900763715, 0.8957923001152803, 0.869823518225835, 0.7319533022167477, 0.8566914602704749, 0.7220513109906921, 1.033769427646449, 0.7882071910743518, 0.7251609441212916, 0.6837727724470654, 0.6655897419825144, 0.6598618792644637, 0.7240129636533953, 0.6760116628734455, 0.6553052926233335, 0.6574338777905635, 0.6495357407144738, 0.6377815223065783, 0.6368005155780984, 0.680296072514 ...

# %%
rolling_predictions = pd.Series(rolling_predictions, index = returns.index[-247:])

# %%
plt.figure(figsize = (10, 4))
true,  = plt.plot(returns[-247:])
preds, = plt.plot(rolling_predictions)
plt.title("Volatility Predictions", fontsize = 20)
plt.legend(["True, returns", "predicted volatility"], fontsize = 16)

# %%
train = returns
model = arch_model(train, p = 1, q = 1)
model_fit = model.fit(disp = "off")

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df.set_index('Date', inplace=True)

last_date = df.index[-1]
last_date
# Out:
# Timestamp('2024-11-11 00:00:00')

# %%
pred = model_fit.forecast(horizon = 20)
future_dates = [last_date + timedelta(days = i) for i in range(1, 21)]
pred = pd.Series(np.sqrt(pred.variance.values[-1,:]), index = future_dates)

# %%
plt.figure(figsize = (15, 5))
plt.plot(pred)
plt.title("Volatility prediction - next 7 days", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Volatility prediction - next 7 days')

# %%
df2 = pd.read_csv("NIFTY 50-12-11-2022-to-11-11-2023.csv")

# %%
df2.head()
# Out:
#          Date      Open      High       Low     Close   Shares Traded   \
# 0  14-NOV-2022  18376.40  18399.45  18311.40  18329.15       301401961
# 1  15-NOV-2022  18362.75  18427.95  18282.00  18403.40       250926391
# 2  16-NOV-2022  18398.25  18442.15  18344.15  18409.65       219268992
# 3  17-NOV-2022  18358.70  18417.60  18312.95  18343.90       200512910
# 4  18-NOV-2022  18382.95  18394.60  18209.80  18307.65       198794846
#
#    Turnover (₹ Cr)
# 0         21697.66
# 1         17836.19
# 2         19732.87
# 3         16410.36
# 4         16553.69

# %%
df2.columns
# Out:
# Index(['Date ', 'Open ', 'High ', 'Low ', 'Close ', 'Shares Traded ',
#        'Turnover (₹ Cr)'],
#       dtype='object')

# %%
df2.columns = df2.columns.str.strip()
df2['Date'] = pd.to_datetime(df2['Date'])

# %%
df2.head()
# Out:
#         Date      Open      High       Low     Close  Shares Traded  \
# 0 2022-11-14  18376.40  18399.45  18311.40  18329.15      301401961
# 1 2022-11-15  18362.75  18427.95  18282.00  18403.40      250926391
# 2 2022-11-16  18398.25  18442.15  18344.15  18409.65      219268992
# 3 2022-11-17  18358.70  18417.60  18312.95  18343.90      200512910
# 4 2022-11-18  18382.95  18394.60  18209.80  18307.65      198794846
#
#    Turnover (₹ Cr)
# 0         21697.66
# 1         17836.19
# 2         19732.87
# 3         16410.36
# 4         16553.69

# %%
len(df2)
# Out:
# 248

# %%
returns = 100 * df2['Close'].pct_change().dropna()
print(returns.head())
# Out:
# 1    0.405092
# 2    0.033961
# 3   -0.357150
# 4   -0.197613
# 5   -0.806767
# Name: Close, dtype: float64

# %%
plt.figure(figsize = (10, 4))
plt.plot(returns)
plt.ylabel("PCT returns", fontsize = 16)
plt.title('Nifty 50 retuns', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Nifty 50 retuns')

# %%
plot_pacf(returns**2)
plt.show()

# %%
model = arch_model(returns, p = 1, q = 1)
model_fit = model.fit()
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 10161.936614668964
# Iteration:      2,   Func. Count:     14,   Neg. LLF: 134056651.27390075
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 229.5281926847931
# Iteration:      4,   Func. Count:     28,   Neg. LLF: 227.297373210081
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 229.47344161817904
# Iteration:      6,   Func. Count:     39,   Neg. LLF: 227.23643377319593
# Iteration:      7,   Func. Count:     44,   Neg. LLF: 227.23639701213642
# Iteration:      8,   Func. Count:     48,   Neg. LLF: 227.23639702070216
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 227.23639701213642
#             Iterations: 8
#             Function evaluations: 48
#             Gradient evaluations: 8

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  Close   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -227.236
# Distribution:                  Normal   AIC:                           462.473
# Method:            Maximum Likelihood   BIC:                           476.510
#                                         No. Observations:                  247
# Date:                Tue, Nov 12 2024   Df Residuals:                      246
# Time:                        12:06:51   Df Model:                            1
#                                  Mean Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# mu             0.0400  4.021e-02      0.994      0.320 [-3.882e-02,  0.119]
#                               Volatility Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# omega          0.3163  7.070e-02      4.473  7.697e-06    [  0.178,  0.455]
# alpha[1]       0.1576  8.455e-02      1.864  6.235e-02 [-8.129e-03,  0.323]
# beta[1]    6.9389e-18      0.208  3.338e-17      1.000    [ -0.407,  0.407]
# ===========================================================================
#
# Covariance estimator: robust
# """

# %%
model = arch_model(returns, p = 1, q = 0)
model_fit = model.fit()
# Out:
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 1134.5511578281098
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 644.0436142553244
# Iteration:      3,   Func. Count:     20,   Neg. LLF: 229.6619296382279
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 6485.5118996935325
# Iteration:      5,   Func. Count:     29,   Neg. LLF: 227.5094574372178
# Iteration:      6,   Func. Count:     33,   Neg. LLF: 227.25391304647576
# Iteration:      7,   Func. Count:     37,   Neg. LLF: 227.23680266179403
# Iteration:      8,   Func. Count:     41,   Neg. LLF: 227.2364100076199
# Iteration:      9,   Func. Count:     45,   Neg. LLF: 227.23639744435644
# Iteration:     10,   Func. Count:     49,   Neg. LLF: 227.2363966993521
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 227.2363966993521
#             Iterations: 10
#             Function evaluations: 49
#             Gradient evaluations: 10

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                       Constant Mean - ARCH Model Results
# ==============================================================================
# Dep. Variable:                  Close   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                       ARCH   Log-Likelihood:               -227.236
# Distribution:                  Normal   AIC:                           460.473
# Method:            Maximum Likelihood   BIC:                           471.001
#                                         No. Observations:                  247
# Date:                Tue, Nov 12 2024   Df Residuals:                      246
# Time:                        12:06:52   Df Model:                            1
#                                  Mean Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# mu             0.0400  4.002e-02      0.999      0.318 [-3.844e-02,  0.118]
#                               Volatility Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# omega          0.3163  3.932e-02      8.043  8.744e-16    [  0.239,  0.393]
# alpha[1]       0.1576  8.114e-02      1.942  5.208e-02 [-1.418e-03,  0.317]
# ===========================================================================
#
# Covariance estimator: robust
# """

# %%
len(returns)
# Out:
# 247

# %%
rolling_predictions = []

testsize = 246

for i in range(testsize):
    train = returns[:-(testsize - i)]
    model = arch_model(train, p=1, q=0)
    model_fit = model.fit(disp="off")
    pred = model_fit.forecast(horizon=1)
    rolling_predictions.append(np.sqrt(pred.variance.values[-1, :][0]))

print("Rolling predictions:", rolling_predictions)
# Out:
# C:\Users\KIIT\AppData\Local\Programs\Python\Python310\lib\site-packages\arch\univariate
242673228054105, 0.6244947442869763, 0.6135632330265222, 0.6510289069756583, 0.6368554358703472, 0.6266739194932605, 0.6121902018638768, 0.639390205325098, 0.6093441891156663, 0.6190444405196093, 0.6502212929411503, 0.619700693042951, 0.610035103647835, 0.6020798621349465, 0.6213685857700987, 0.6318722616121836, 0.5978973740909801, 0.6355593226534089, 0.655432840651361, 0.7165767794648573, 0.6413586163371106, 0.6057061351200677, 0.5937168935568135, 0.6148093178320384, 0.6777022762195561, 0.595624068798129, 0.6082093061891246, 0.6031634771450594, 0.5898737067428023, 0.6445190626513613, 0.6408244266001781, 0.5903532942329758, 0.6009832694270787, 0.6353275728161271, 0.7461971226140555, 0.6110690808331973, 0.5896980914268053, 0.6092470654598345, 0.6343620797731823, 0.5892581071562282, 0.6128063887101413, 0.5875294581588458, 0.7037926102024613, 0.6527207508098609, 0.6340808043144058, 0.6041186150807693, 0.5924203459534146, 0.5939875381807578, 0.6129340864748788, 0.6278226239288284, 0.5852846015739415, 0.5839172560760061, 0.6151130669839149, 0.5929004246015074, 0.5965795064624526, 0.5781965220375327, 0.5803201379213614, 0.5873049018022062, 0.6234182900227624, 0.5773275798585901, 0.5743168343248848, 0.5693172805486786, 0.6007270129880461, 0.6611656900610847, 0.592553653755511 ...

# %%
rolling_predictions = pd.Series(rolling_predictions, index = returns.index[-246:])

# %%
plt.figure(figsize = (10, 4))
true,  = plt.plot(returns[-246:])
preds, = plt.plot(rolling_predictions)
plt.title("Volatility Predictions", fontsize = 20)
plt.legend(["True, returns", "predicted volatility"], fontsize = 16)

# %%
train = returns
model = arch_model(train, p = 1, q = 0)
model_fit = model.fit(disp = "off")

# %%
df2['Date'] = pd.to_datetime(df2['Date'], errors='coerce')
df2.set_index('Date', inplace=True)

last_date = df2.index[-1]
last_date
# Out:
# Timestamp('2023-11-10 00:00:00')

# %%
combined_df
# Out:
#                 Open      High       Low     Close  Shares Traded  \
# Date
# 2022-11-14  18376.40  18399.45  18311.40  18329.15    301401961.0
# 2022-11-15  18362.75  18427.95  18282.00  18403.40    250926391.0
# 2022-11-16  18398.25  18442.15  18344.15  18409.65    219268992.0
# 2022-11-17  18358.70  18417.60  18312.95  18343.90    200512910.0
# 2022-11-18  18382.95  18394.60  18209.80  18307.65    198794846.0
# ...              ...       ...       ...       ...            ...
# NaT         23916.50  24229.05  23842.75  24213.30    289511197.0
# NaT         24308.75  24537.60  24204.05  24484.05    351082031.0
# NaT         24489.60  24503.35  24179.05  24199.35    322185588.0
# NaT         24207.70  24276.15  24066.65  24148.20    298725122.0
# NaT         24087.25  24336.80  24004.60  24141.30    273370562.0
#
#             Turnover (₹ Cr)
# Date
# 2022-11-14         21697.66
# 2022-11-15         17836.19
# 2022-11-16         19732.87
# 2022-11-17         16410.36
# 2022-11-18         16553.69
# ...                     ...
# NaT                30074.77
# NaT                34108.84
# NaT                30971.89
# NaT                27670.30
# NaT                26600.28
#
# [497 rows x 6 columns]

# %%
pred = model_fit.forecast(horizon = 20)
future_dates = [last_date + timedelta(days = i) for i in range(1, 21)]
pred = pd.Series(np.sqrt(pred.variance.values[-1,:]), index = future_dates)

# %%
plt.figure(figsize = (15, 5))
plt.plot(pred)
plt.title("Volatility prediction - next 7 days", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Volatility prediction - next 7 days')
